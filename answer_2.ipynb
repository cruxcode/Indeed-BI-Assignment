# %% [markdown]
# ## Problem Statement
# <ol style="font-size: 20px">
#     <li>How many injuries in this dataset involve a skateboard?</li>
#     <li>Of those injuries, what percentage were male and what percentage were female?</li>
#     <li>What was the average age of someone injured in an incident involving a skateboard?</li>
# </ol>

# %% [markdown]
# ## Approach
# <p style="font-size: 20px"> The analysis has three steps as follows: </p>
# <ol style="font-size: 20px">
#     <li> Find all incidents involving skateboards. Narrative of each row is checked for occurence of word similar to "skateboard" using regular expressions and levenshtein distance algorithm for more accuracy. Regular expressions can't address for the errors inside the word but levenshtein can. Levenshtein can address for errors in suffix and prefix of word but regular expressions can. </li>
#     <li> Calculate percentages of male and female with injuries involving skateboard. </li>
#     <li> Calculate mean age of people with injuries involving skateboard. </li>
# </ol>

# %%
# Loading project configuiration
# %run 'load_files.ipynb'

# %%
import re
import distance

# %% [markdown]
# ## Step 1: Finding skateboard and similar words in narrative

# %%
# Spellcheck using levenshtein distance algorithm
def match_distance(words, string):
    components = re.split("[\s/.]+", string)
    for component in components:
        for word in words:
            result = distance.levenshtein(word.lower(), component.lower())
            if result <= 4:
                return result
    return -1

# %%
# Function to be used with apply method later
def apply_distance_check(x):
    patterns = ['skateboard', 'skateboarding', 'skateboarder']
    return match_distance(patterns, x)

# %%
# Spellcheck using Regex
def match_regex(pattern, string):
    searcher = re.compile(pattern, re.IGNORECASE)
    if searcher.search(string):
        return 1
    return -1

# %%
# Function to be used with apply method later
def apply_regex_check(x):
    pattern = 'skateboard'
    return match_regex(pattern, x)

# %%
# Creating a copy of main_df to modify in later steps
skateboard_df = main_df
# Applying distance function for spellcheck
skateboard_df["is_skateboard_distance"] = main_df["narrative"].apply(apply_distance_check)

# %% [markdown]
# <b>Frequency distribution at different levenshtein distances</b>

# %%
skateboard_df["is_skateboard_distance"].value_counts()
# Out:
# -1    64760
#  0      271
#  4      269
#  3      163
#  1       24
#  2       12
# Name: is_skateboard_distance, dtype: int64

# %%
# Applying regex function for spellcheck
skateboard_df["is_skateboard_regex"] = main_df["narrative"].apply(apply_regex_check)

# %% [markdown]
# <b>Frequency distribution for regex matches, 1 implies match and -1 no match</b>

# %%
skateboard_df["is_skateboard_regex"].value_counts()
# Out:
# -1    65033
#  1      466
# Name: is_skateboard_regex, dtype: int64

# %% [markdown]
# <b> Next four cells helps to find the critical distance to be considered. Distance of 2 is taken to be critical & also corresponds to general notions of NLP. </b>

# %%
skateboard_df[(skateboard_df["is_skateboard_distance"] ==4) & (skateboard_df["is_skateboard_regex"] == -1)]
# Out:
#        CPSC Case # trmt_date  psu   weight stratum  age     sex  \
# 321      140160553   1/20/14   90   6.6704       C   15  Female
# 385      141240274  12/15/14   99  82.3076       S   46  Female
# 495      140300468   1/25/14   54  41.0402       M   17    Male
# 829      140213960   1/27/14   59  80.0213       S   22    Male
# 832      140341835    3/9/14   59  80.0213       S   35  Female
# 840      140244597   2/12/14   59  80.0213       S   24    Male
# 853      140148124   1/18/14   59  80.0213       S   14    Male
# 859      140341831   3/10/14   59  80.0213       S   18  Female
# 860      140312386   2/20/14   59  80.0213       S   12  Female
# 896      140213958   1/26/14   59  80.0213       S   15  Female
# 904      140231001    2/2/14   59  80.0213       S   14    Male
# 916      140312372   2/25/14   59  80.0213       S   10  Female
# 2456     140242716    2/6/14   36  80.0213       S   21    Male
# 2458     140242725   2/13/14   36  80.0213       S   10    Male
# 2460     140149404   1/20/14   36  80.0213       S   16    Male
# 2461     140123512    1/4/14   36  80.0213       S   12    Male
# 2462     140161914   1/17/14   36  80.0213       S   17    Male
# 2463     140216021    2/3/14   36  80.0213       S   26    Male
# 2478     140344526    3/4/14   36  80.0213       S   14  Female
# 2497     140161916   1/17/14   36  80.0213       S   18  Female
# 2505     140324312   2/22/14   36  80.0213       S   14    Male
# 2520     140439194    4/5/14   36  80.0213       S   22  Female
# 2858     141042021  10/14/14   51  74.3851       L   45  Female
# 3720     140308067    3/2/14   85  80.0213       S   15    Male
# 3983     140962243   9/27/14   84  82.3076       S   17  Female
# 4834     141032773  10/10/14   81  82.3076       S   17    Male
# 4967     141005549   9/26/14   90   5.7174       C   12    Male
# 4985     141145877  11/20/14   99  82.3076       S    7    Male
# 5068     140401278   3/23/14   99  80.0213       S   13    Male
# 5454     140348314   3/18/14   59  80.0213       S   33    Male
# ...            ...       ...  ...      ...     ...  ...     ...
# 50985    140520774    5/6/14   17  14.3089       V  223  Female
# 52256    140253276   2/21/14   90   5.7174       C   12    Male
# 53381    140307201   2/18/14   44  74.3851       L   15    Male
# 53392    141139417   11/5/14   44  74.3851       L   19    Male
# 53543    141256379    7/6/14   42  74.3851       L   72  Female
# 53673    140904716    8/2/14   53  15.6716       V  213    Male
# 54296    140955838   9/15/14   31   5.7174       C    2  Female
# 54721    141067539  10/25/14   16  99.7040       M   55    Male
# 54931    140619252   5/30/14   35  14.3089       V   19    Male
# 54953    141114780   11/1/14    8   5.7174       C   12    Male
# 55431    140321307    3/1/14   34  14.3089       V   33    Male
# 55446    140134500    1/6/14   67  14.3089       V   29  Female
# 55933    140222941   1/10/14   14  41.0402       M    5  Female
# 57229    141249011  12/16/14   42  74.3851       L   10    Male
# 57626    140501622   3/16/14   32   5.7174       C    3  Female
# 57642    140913036   1/29/14   32   6.6704       C    2    Male
# 57691    140242642    1/1/14    6  80.0213       S   76  Female
# 58023    150102090  12/30/14   31   5.7174       C   16    Male
# 58179    140615831   2/17/14   40  14.3089       V   17  Female
# 59044    140249449   2/16/14   34  14.3089       V   50    Male
# 61496    140320274    3/5/14   18   5.7174       C  209    Male
# 61504    150112363  12/29/14   18   5.7174       C    8    Male
# 62471    140309904   2/26/14    7  80.0213       S   15    Male
# 62688    140128777    1/4/14   68  81.5760       M   44    Male
# 63239    150216938   7/15/14   63  99.7040       M    4    Male
# 63596    140426191    4/2/14   64  14.3089       V   31    Male
# 63646    140238636   2/17/14   95  14.3089       V   25    Male
# 63724    140515183   4/29/14   22  14.3089       V   71    Male
# 64953    140450890   3/19/14   32   5.7174       C    3  Female
# 65477    140239817   2/17/14   21  14.3089       V   23    Male
#
#                          race race_other  diag diag_other  body_part  \
# 321                     Asian        NaN    64        NaN         92
# 385               None listed        NaN    71  KNEE PAIN         35
# 495                     White        NaN    64        NaN         34
# 829                     White        NaN    52        NaN         75
# 832                     White        NaN    52        NaN         75
# 840                     White        NaN    59        NaN         88
# 853                     White        NaN    52        NaN         75
# 859                     White        NaN    64        NaN         33
# 860                     White        NaN    57        NaN         34
# 896                     White        NaN    64        NaN         35
# 904                     White        NaN    57        NaN         37
# 916                     White        NaN    64        NaN         34
# 2456                    White        NaN    52        NaN         75
# 2458                    White        NaN    57        NaN         32
# 2460                    White        NaN    57        NaN         30
# 2461                    White        NaN    57        NaN         34
# 2462                    White        NaN    52        NaN         75
# 2463                    White        NaN    53        NaN         33
# 2478                    White        NaN    52        NaN         75
# 2497                    White        NaN    57        NaN         34
# 2505                    White        NaN    57        NaN         34
# 2520                    White        NaN    59        NaN         38
# 2858   Black/African American        NaN    62        NaN         75
# 3720                    White        NaN    53        NaN         75
# 3983                    White        NaN    64        NaN         34
# 4834                    White        NaN    59        NaN         92
# 4967                    White        NaN    59        NaN         92
# 4985              None listed        NaN    53        NaN         36
# 5068                    White        NaN    62        NaN         75
# 5454                    White        NaN    56        NaN         77
# ...                       ...        ...   ...        ...        ...
# 50985             None listed        NaN    57        NaN         80
# 52256      Other / Mixed Race   HISPANIC    57        NaN         33
# 53381                   White        NaN    64        NaN         37
# 53392                   White        NaN    59        NaN         32
# 53543                   White        NaN    59        NaN         36
# 53673                   White        NaN    59        NaN         88
# 54296      Other / Mixed Race    UNKNOWN    62        NaN         75
# 54721                   White        NaN    59        NaN         92
# 54931                   White        NaN    59        NaN         83
# 54953                   White        NaN    57        NaN         33
# 55431                   White        NaN    64        NaN         33
# 55446             None listed        NaN    64        NaN         34
# 55933  Black/African American        NaN    59        NaN         76
# 57229                   White        NaN    59        NaN         76
# 57626  Black/African American        NaN    59        NaN         75
# 57642  Black/African American        NaN    62        NaN         75
# 57691                   White        NaN    57        NaN         31
# 58023                   White        NaN    62        NaN         31
# 58179                   White        NaN    52        NaN         75
# 59044  Black/African American        NaN    53        NaN         77
# 61496             None listed    UNKNOWN    62        NaN         75
# 61504                   White        NaN    59        NaN         36
# 62471             None listed        NaN    64        NaN         34
# 62688                   White        NaN    71       PAIN         35
# 63239             None listed        NaN    59        NaN         76
# 63596  Black/African American        NaN    57        NaN         82
# 63646                   White        NaN    53        NaN         35
# 63724                   White        NaN    51        NaN         92
# 64953                   White        NaN    57        NaN         89
# 65477             None listed        NaN    53        NaN         30
#
#        disposition  location  fmv  prod1   prod2  \
# 321              1         9    0   5031     NaN
# 385              1         0    0   1114     NaN
# 495              1         9    0   5031     NaN
# 829              1         9    0   5031     NaN
# 832              1         9    0   5031     NaN
# 840              1         9    0   5031     NaN
# 853              1         9    0   5031     NaN
# 859              1         9    0   5031     NaN
# 860              1         9    0   5031     NaN
# 896              1         9    0   5031     NaN
# 904              1         9    0   5031     NaN
# 916              1         9    0   5031     NaN
# 2456             1         9    0   5031     NaN
# 2458             1         9    0   5031     NaN
# 2460             1         9    0   5031     NaN
# 2461             1         9    0   5031     NaN
# 2462             1         9    0   5031     NaN
# 2463             1         9    0   5031     NaN
# 2478             1         9    0   5031     NaN
# 2497             1         9    0   5031     NaN
# 2505             1         9    0   5031     NaN
# 2520             1         9    0   5031     NaN
# 2858             1         0    0   4076     NaN
# 3720             1         9    0   5031     NaN
# 3983             1         1    0   4076  1884.0
# 4834             1         1    0    464  1114.0
# 4967             1         8    0    836  1114.0
# 4985             1         1    0   5031     NaN
# 5068             1         9    0   5031     NaN
# 5454             1         9    0   5031     NaN
# ...            ...       ...  ...    ...     ...
# 50985            1         1    0   4076  4010.0
# 52256            1         9    0   5031     NaN
# 53381            1         9    0   5031     NaN
# 53392            1         9    0   5031     NaN
# 53543            1         1    0   1114     NaN
# 53673            1         1    0   4076     NaN
# 54296            1         1    0   4076     NaN
# 54721            1         1    0   1114   464.0
# 54931            1         9    0   1261     NaN
# 54953            1         9    0   3255     NaN
# 55431            1         9    0   5031     NaN
# 55446            1         9    0   5031     NaN
# 55933            1         1    0   4076     NaN
# 57229            1         1    0   4008  4076.0
# 57626            1         1    0   4076     NaN
# 57642            1         0    0   4076     NaN
# 57691            1         1    0   4076     NaN
# 58023            4         0    0   5031     NaN
# 58179            1         9    0   5031     NaN
# 59044            1         0    0   1114     NaN
# 61496            1         1    0   4076     NaN
# 61504            1         9    0   3255     NaN
# 62471            1         9    0   5031     NaN
# 62688            1         9    0   5031     NaN
# 63239            1         1    0   4076     NaN
# 63596            1         0    0   4076     NaN
# 63646            1         9    0   5031     NaN
# 63724            1         1    2   1114     NaN
# 64953            4         1    0   4076     NaN
# 65477            1         9    0   5031     NaN
#
#                                                narrative  \
# 321    15 YOF WAS SNOWBOARDING IN THE SKI AREA, & CAU...
# 385    46YOF WAS MOVING CARBOARD BOX WITH HER LEG AND...
# 495    17YOM SNOWBOARDING, FELL; SNOWBOARD HIT KNEE/J...
# 829    22 YO MALE FELL WHILE SNOWBOARDING HITTING HEA...
# 832    35 YO FEMALE FELL WHILE SNOWBOARDING HITTING H...
# 840    24 YO MALE FELL WHILE SNOWBOARDING HITTING LIP...
# 853    14 YO MALE FELL WHILE SNOWBOARDING , DX CONCUS...
# 859    18 YO FEMALE FELL WHILE SNOWBOARDING , DX SPRA...
# 860    12 YO FEMALE FELL WHILE SNOWBOARDING , DX FX W...
# 896    15 YO FEMALE FELL WHILE SNOWBOARDING , DX KNEE...
# 904    14 YO MALE FELL WHILE SNOWBOARDING , DX ANKLE FX
# 916    10 YO FEMALE FELL WHILE SNOWBOARDING INJ, WRIS...
# 2456   21 YOM WAS SNOWBOARDING AND TRIED TO DO A 180 ...
# 2458   10 YOM WAS SNOWBOARDING AND COMPLAINS OF ELBOW...
# 2460   16 YOM WAS SNOWBOARDING AND WAS GOING OVER AN ...
# 2461   12 YOM WAS SNOWBOARDING AND FELL ONTO HIS WRIS...
# 2462   17 YOM WAS SNOWBOARDING AND FELL STRIKING HIS ...
# 2463   26 YOM WAS SNOWBOARDING AND FELL, WAS GETTING ...
# 2478   14 YOF WAS SNOWBOARDING AND FELL STRIKING HER ...
# 2497   18 YOF WAS SNOWBOARDING AND FELL FORWARD LANDI...
# 2505   14 YOM WAS SNOWBOARDING AND FELL INJURING WRIS...
# 2520   22 YOF WAS SNOWBOARDING AND AS SHE GOT OFF LIF...
# 2858   45 YO F, C/O HEADACHE 1 DAY SAYS LAST NIGHT AR...
# 3720   15YOM WAS SNOWBOARDING AND FELL HIT HEAD.+ LOC...
# 3983   17 YOF, PT GOT WRIST CAUGHT BETWEEN HEADBOARD ...
# 4834   17YOM CUTTING OPEN CARDBOARD BOX W KNIFE, KNIF...
# 4967   12 YOM  WAS IN SHOP CLASS, AT SCHOOL & CUT HIS...
# 4985   7YOM WAS OUTSIDE AT GRADPARENTS HOME AND FELL ...
# 5068              13YOM HIT HEAD SNOWBOARDING/ MILD TBI
# 5454   33 YO MALE WHILE SNOWBOARDING GOT UNKNOWN OBJE...
# ...                                                  ...
# 50985  23MO OLD F GOT ARM STUCK BETWEEN FOOTBOARD & M...
# 52256  12 YOM FELL WHILE SNOWBOARDING , 3 WEEKS AGO, ...
# 53381     15 YOM SNOWBOARDING ACCIDENT. DX ANKLE SPRAIN
# 53392  19 YOM INJURY TO ELBOW SNOWBOARDING. DX ELBOW ...
# 53543  72YOF LAC TO RLE WHEN HIT LEG INTO CARDBOARD B...
# 53673  13MOM-LIPS LAC-HIT LIPS ON HEADBOARD WHILE ON ...
# 54296  2 YO FEMALE STANDING ON BED AND FELL, HIT HEAD...
# 54721  55 YOM STATES WAS CUTTING CARDBOARD WITH A KNI...
# 54931  19YOM CUT RIGHT FOOT ON SURFBOARD AT BEACH FOO...
# 54953  12YOM FELL WHILE ICE SKATING WHEN COLLIDED WIT...
# 55431  33 YM FELL WHILE SNOWBOARDING INJURING BOTH AR...
# 55446  DX SPRAIN WRIST/HAND 29YOF S/P FALL SNOWBOARDI...
# 55933  5YOF  PT HIT HEAD ON HEADBOARD OF BED AT HOME....
# 57229  10YOM LAC TO FACE WHEN SPINNING IN A BLANKET A...
# 57626  3 YOF WAS JUMPING ON THE BED FELL STRIKING HEA...
# 57642  2YOM JUMPING ON BED, HIT HEAD ON HEADBOARD WHI...
# 57691  76 YOF FELL ONTO THE FOOTBOARD OF HER BED AND ...
# 58023  16 YO MALE FELL WHILE SNOWBOARDING.  DX SPLEEN...
# 58179  17YOF WAS SNOWBOARDING TODAY, FELL DOWN & STRU...
# 59044  50 YM WAS STRUCK IN THE EYE W/CORNER OF CARDBO...
# 61496  9 MOM PLAYING ON THE BED, STUMBLED AND HIT HEA...
# 61504  8 YOM COLLIDED WITH ANOTHER ICE SKATER.  DX:  ...
# 62471   15 Y O M SPRAINED WRIST  IN A FALL SNOWBOARDING
# 62688        44YOM KNEE PAIN INJURED WHILE SNOWBOARDING
# 63239  4YOM JUMPING ON THE BED AND STRUCK FACE ON THE...
# 63596  31YOM C/O HAND PAIN. PT STATES HE HIT HIS HAND...
# 63646  LEFT KNEE CONT.25YOM WAS SNOWBOARDING AND INJU...
# 63724  PT WAS BURNING TRASH AND BURNED FINGERS ON BUR...
# 64953  3 YOF FELL ON FOOTBOARD OF THE BED DX CERVICAL...
# 65477  23YM FELL ONTO SHOULDER WHILE SNOWBOARDING ON ...
#
#        is_skateboard_distance  is_skateboard_regex
# 321                         4                   -1
# 385                         4                   -1
# 495                         4                   -1
# 829                         4                   -1
# 832                         4                   -1
# 840                         4                   -1
# 853                         4                   -1
# 859                         4                   -1
# 860                         4                   -1
# 896                         4                   -1
# 904                         4                   -1
# 916                         4                   -1
# 2456                        4                   -1
# 2458                        4                   -1
# 2460                        4                   -1
# 2461                        4                   -1
# 2462                        4                   -1
# 2463                        4                   -1
# 2478                        4                   -1
# 2497                        4                   -1
# 2505                        4                   -1
# 2520                        4                   -1
# 2858                        4                   -1
# 3720                        4                   -1
# 3983                        4                   -1
# 4834                        4                   -1
# 4967                        4                   -1
# 4985                        4                   -1
# 5068                        4                   -1
# 5454                        4                   -1
# ...                       ...                  ...
# 50985                       4                   -1
# 52256                       4                   -1
# 53381                       4                   -1
# 53392                       4                   -1
# 53543                       4                   -1
# 53673                       4                   -1
# 54296                       4                   -1
# 54721                       4                   -1
# 54931                       4                   -1
# 54953                       4                   -1
# 55431                       4                   -1
# 55446                       4                   -1
# 55933                       4                   -1
# 57229                       4                   -1
# 57626                       4                   -1
# 57642                       4                   -1
# 57691                       4                   -1
# 58023                       4                   -1
# 58179                       4                   -1
# 59044                       4                   -1
# 61496                       4                   -1
# 61504                       4                   -1
# 62471                       4                   -1
# 62688                       4                   -1
# 63239                       4                   -1
# 63596                       4                   -1
# 63646                       4                   -1
# 63724                       4                   -1
# 64953                       4                   -1
# 65477                       4                   -1
#
# [256 rows x 20 columns]

# %%
skateboard_df[(skateboard_df["is_skateboard_distance"] ==3) & (skateboard_df["is_skateboard_regex"] == -1)]
# Out:
#        CPSC Case # trmt_date  psu   weight stratum  age     sex  \
# 3041     140142351   1/19/14   21  14.3089       V   32    Male
# 6341     140807200   7/21/14  101  99.7040       M   19    Male
# 8607     140753193   7/24/14   84  87.2960       S   10  Female
# 21393    141046727  10/13/14   65  82.3076       S   36    Male
# 22136    150115269  12/27/14   68  99.7040       M   28    Male
# 23297    140332847   3/12/14   95  14.3089       V   22    Male
# 24355    140713606   6/21/14  101  89.7336       M   20  Female
# 26150    140834344   8/13/14   85  82.3076       S   17    Male
# 28921    150135203  12/26/14   66  82.3076       S   12  Female
# 31556    140741047   5/14/14   14  41.0402       M   45    Male
# 35853    150228275   7/18/14   63  99.7040       M   13    Male
# 36347    140727573    7/4/14   86  87.2960       S   25    Male
# 39443    140145931   1/13/14   68  81.5760       M   57    Male
# 41903    140433718    4/8/14   25  14.3089       V   23  Female
# 47503    141059073  10/25/14   73  82.3076       S   18    Male
# 51147    140451164   4/13/14    3  74.3851       L   16    Male
# 59850    140828928   7/15/14   54  50.1602       M   10  Female
# 62349    141139679  11/15/14    8   5.7174       C   10    Male
#
#                          race race_other  diag diag_other  body_part  \
# 3041              None listed        NaN    59        NaN         93
# 6341              None listed        NaN    55        NaN         30
# 8607                    White        NaN    52        NaN         75
# 21393                   White        NaN    51        NaN         32
# 22136                   White        NaN    57        NaN         82
# 23297      Other / Mixed Race   HISPANIC    62        NaN         75
# 24355             None listed        NaN    71       PAIN         31
# 26150                   White        NaN    52        NaN         75
# 28921             None listed        NaN    53        NaN         83
# 31556                   White        NaN    64        NaN         80
# 35853             None listed        NaN    59        NaN         79
# 36347             None listed        NaN    64        NaN         83
# 39443                   White        NaN    62        NaN         75
# 41903  Black/African American        NaN    53        NaN         92
# 47503             None listed        NaN    59        NaN         75
# 51147             None listed        NaN    59        NaN         76
# 59850                   White        NaN    64        NaN         37
# 62349  Black/African American        NaN    59        NaN         83
#
#        disposition  location  fmv  prod1   prod2  \
# 3041             1         1    0   4076     NaN
# 6341             1         9    0   1264     NaN
# 8607             1         1    0   1884     NaN
# 21393            1         1    0    312     NaN
# 22136            1         9    0   5040     NaN
# 23297            1         1    0   1842  1893.0
# 24355            1         9    0   1264     NaN
# 26150            1         9    0   1264     NaN
# 28921            1         1    0   1884     NaN
# 31556            1         9    0    852  1264.0
# 35853            1         9    0   1261     NaN
# 36347            1         9    0   1264     NaN
# 39443            1         1    0    312     NaN
# 41903            1         0    0    572  1819.0
# 47503            1         9    0   1264     NaN
# 51147            1         9    0   5040     NaN
# 59850            1         9    0   1264     NaN
# 62349            1         1    0   1884     NaN
#
#                                                narrative  \
# 3041   32YM ACC STUBBED TOE AGAINST THE BASEBOARD OF ...
# 6341   19YOM WAS WAKEBOARDING AND INJURED LEFT SHOULD...
# 8607   10 YOF,PT HAS RECENT H\O OF CONCUSSION. HAS BE...
# 21393  36YOM WITH SECOND DEGREE BURNS TO RIGHT ELBOW ...
# 22136  28YOM FRACTURED HAND FELL WHILE RIDING HIS BIK...
# 23297  CHI. 22 YOM MISSED LAST STEP HITTING HEAD ON B...
# 24355  20YOF COMPLAINED OF BACK PAIN AFTER WAKEBOARDI...
# 26150  17YOM FELL WHILE WAKEBOARDING POSSIBLE CONCUSS...
# 28921  TOE CONT.: 12YOF BROTHER STOLE GIFT FROM HER, ...
# 31556  45YOM  R UPPER ARM CAUGHT IN ROPE WHILE WATERB...
# 35853  13YOM WAS SKINBOARDING AT THE BEACH AND LANDED...
# 36347  25 YOM WIPED OUT ON A WAKEBOARD. NOW HAS RT FO...
# 39443  57YOM CLOSED HEAD INJURY, LACERATIONS TO FACE ...
# 41903  A 23YOF CAUGHT FINGER BETWEEN TV & BASEBOARD W...
# 47503  18YOM WAS WAKEBOARDING AND CRASHED SUSTAINED A...
# 51147  16YOM FELL OFF BIKE WHILE GOING OFF JUMP AT SK...
# 59850  10YOF INJURED RT ANKLE @ CAMP WHEN WAKEBOARDIN...
# 62349    10YOM HIT FOOT ON BASEBOARD AT HOME; FOOT LAC.
#
#        is_skateboard_distance  is_skateboard_regex
# 3041                        3                   -1
# 6341                        3                   -1
# 8607                        3                   -1
# 21393                       3                   -1
# 22136                       3                   -1
# 23297                       3                   -1
# 24355                       3                   -1
# 26150                       3                   -1
# 28921                       3                   -1
# 31556                       3                   -1
# 35853                       3                   -1
# 36347                       3                   -1
# 39443                       3                   -1
# 41903                       3                   -1
# 47503                       3                   -1
# 51147                       3                   -1
# 59850                       3                   -1
# 62349                       3                   -1

# %%
skateboard_df[(skateboard_df["is_skateboard_distance"] ==2) & (skateboard_df["is_skateboard_regex"] == -1)]
# Out:
#        CPSC Case # trmt_date  psu   weight stratum  age     sex  \
# 16066    140548417   5/23/14   78  81.5760       M   17    Male
# 17888    140703075   6/24/14   67  14.3089       V   21    Male
# 20239    150234735   7/27/14   42  74.3851       L   16    Male
# 42393    140333396   3/12/14   51  74.3851       L   50    Male
# 47131    140660659   6/21/14   17  14.3089       V   21    Male
# 50558    141123371   11/8/14   21  15.6716       V   19  Female
# 52554    140553148   5/25/14   95  14.3089       V   29    Male
# 56596    140430392    4/9/14   58  14.3089       V   18    Male
# 56763    140755832   7/20/14   37   5.7174       C    5    Male
#
#                      race race_other  diag diag_other  body_part  disposition  \
# 16066         None listed        NaN    53        NaN         87            1
# 17888         None listed        NaN    53        NaN         80            1
# 20239  Other / Mixed Race   HISPANIC    57        NaN         75            1
# 42393  Other / Mixed Race   HISPANIC    57        NaN         33            1
# 47131         None listed        NaN    57        NaN         76            5
# 50558         None listed        NaN    64        NaN         34            1
# 52554               White        NaN    64        NaN         35            1
# 56596         None listed        NaN    57        NaN         30            1
# 56763         None listed        NaN    59        NaN         76            1
#
#        location  fmv  prod1  prod2  \
# 16066         0    0   1333    NaN
# 17888         0    0   1333    NaN
# 20239         5    0   1333    NaN
# 42393         0    0   1333  676.0
# 47131         4    0   1333    NaN
# 50558         0    0   1333    NaN
# 52554         4    0   1333    NaN
# 56596         0    0   1333    NaN
# 56763         0    0   1333    NaN
#
#                                                narrative  \
# 16066  17 YOM NJURED AFTER FALLING OFF SKATEBAORD. DX...
# 17888  DX RT UPPER EXT SKIN ABRASION 21YOM ROAD RASH ...
# 20239  16YOM PAIN TO HEAD WHEN FALL TO GROUND WHILE S...
# 42393  50 YO M,LAST NIGHT PLAYING W/ DAUGHTER,SHOWING...
# 47131                21YOM FX MANDIBLE- FELL SKATEBAORD
# 50558  19YF WRIST PAIN SINCE FOOSH FROM SKATEOBARD YT...
# 52554  RT KNEE STRAIN.29YOM WAS SKATEBAORDING AND PUT...
# 56596  AN 18 YOM FELL WHILE SAKTEBOARDING AND INJURED...
# 56763  5 YO M WAS PLAYING W/ ANOTHER CHILD WHEN HE WA...
#
#        is_skateboard_distance  is_skateboard_regex
# 16066                       2                   -1
# 17888                       2                   -1
# 20239                       2                   -1
# 42393                       2                   -1
# 47131                       2                   -1
# 50558                       2                   -1
# 52554                       2                   -1
# 56596                       2                   -1
# 56763                       2                   -1

# %%
skateboard_df[(skateboard_df["is_skateboard_distance"] ==1) & (skateboard_df["is_skateboard_regex"] == -1)]
# Out:
#       CPSC Case # trmt_date  psu   weight stratum  age     sex   race  \
# 8724    140701314   6/23/14   68  89.7336       M    9  Female  White
#
#      race_other  diag diag_other  body_part  disposition  location  fmv  \
# 8724        NaN    64        NaN         34            1         5    0
#
#       prod1  prod2                                          narrative  \
# 8724   1333    NaN  9YOF SPRAINED WRIST FELL OFF HER SKATEBOAD ONT...
#
#       is_skateboard_distance  is_skateboard_regex
# 8724                       1                   -1

# %%
# Creating final flag for skateboard involved
def create_final_flag(x):
    if (x["is_skateboard_distance"] <=2 and x["is_skateboard_distance"] >= 0) or x["is_skateboard_regex"] == 1:
        return 1
    else:
        return 0

skateboard_df["is_skateboard_final"] = skateboard_df.apply(create_final_flag, axis=1)

# %% [markdown]
# ## Step 1 Answer: Total number of Skatedboard related injuries = 476

# %%
total_skateboard_injuries = skateboard_df["is_skateboard_final"].value_counts()[1]
print("Number of injuries associated with skateboard is", total_skateboard_injuries)
# Out:
# Number of injuries associated with skateboard is 476

# %% [markdown]
# ## Step 2: Percentages of males and females with injuries involving skateboard

# %%
# Checking for missing values in sex column
print("Number of missing values", num_missing(main_df, 'sex'))
# Checking for labels of sex variable
skateboard_df["sex"].value_counts()
# Out:
# Number of missing values 0
# Male      35503
# Female    29996
# Name: sex, dtype: int64

# %%
# Get female and male injuries related to skateboard
female_skateboard_injuries = skateboard_df[skateboard_df["is_skateboard_final"] == 1] \
                                .groupby(["sex"])["is_skateboard_final"].sum()["Female"]
male_skateboard_injuries = skateboard_df[skateboard_df["is_skateboard_final"] == 1] \
                                .groupby(["sex"])["is_skateboard_final"].sum()["Male"]

# %% [markdown]
# ## Step 2 Answer:
# <p style="font-size: 20px">Male Percentage with such injuries = 82.35 %</p>
# <p style="font-size: 20px">Female Percentage with such injuries = 17.65 %</p>

# %%
# Get %female and %male of the total injuries related to skateboard
male_percentage = (male_skateboard_injuries / total_skateboard_injuries) * 100
female_percentage = (female_skateboard_injuries / total_skateboard_injuries) * 100
print("Male percentage of total injuries related with skateboard", male_percentage, "%")
print("Female percentage of total injuries related with skateboard", female_percentage, "%")
# Out:
# Male percentage of total injuries related with skateboard 82.35294117647058 %
# Female percentage of total injuries related with skateboard 17.647058823529413 %

# %% [markdown]
# ## Step 3: Average age of someone with injury involving skateboard

# %%
# Checking for missing values in sex column
print("Number of missing values", num_missing(main_df, 'age'))
# Out:
# Number of missing values 0

# %% [markdown]
# ## Step 3 Answer: Mean Age = 18 years(approx)

# %%
mean_age = skateboard_df[skateboard_df["is_skateboard_final"] == 1]["age"].mean()
print("Mean age of people injuries related to skateboard", mean_age, "years.")
# Out:
# Mean age of people injuries related to skateboard 18.044117647058822 years.
